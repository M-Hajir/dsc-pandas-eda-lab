# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Set matplotlib inline
# %matplotlib inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Load the data
df = pd.read_csv('data/ames.csv', index_col=0)

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg  \
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature
# Id                                    ...
# ...

# %%
# Run this cell without changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# 'SalePrice' distribution
df['SalePrice'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Summary statistics for 'SalePrice' using pandas statistics functions
print('Mean:', df['SalePrice'].mean())
print('Median:', df['SalePrice'].median())
print('Standard Deviation:', df['SalePrice'].std())
# Out:
# Mean: 180921.19589041095
# Median: 163000.0
# Standard Deviation: 79442.50288288662

# %% [markdown]
# In the cell below, interpret the above information.

# %%
"""
The mean (or average) SalePrice is 180921.20 dollars. This means that if we add up all the SalePrices in our dataset and divide by the total number of observations, we get an average of 180921.20 dollars.

The median SalePrice is 163000.0 dollars. This means that half of the observations have a SalePrice lower than 163000.0 dollars, and half of the observations have a SalePrice higher than 163000.0 dollars.

The standard deviation of SalePrice is 79442.50 dollars. This indicates how much variation or dispersion there is in the SalePrice values. A low standard deviation means that the data points tend to be very close to the mean, while a high standard deviation means that the data points are spread out over a wider range of values. In this case, the standard deviation is relatively high, which suggests that the SalePrice values are quite spread out.
"""
# Out:
# '\nThe mean (or average) SalePrice is 180921.20 dollars. This means that if we add up all the SalePrices in our dataset and divide by the total number of observations, we get an average of 180921.20 dollars.\n\nThe median SalePrice is 163000.0 dollars. This means that half of the observations have a SalePrice lower than 163000.0 dollars, and half of the observations have a SalePrice higher than 163000.0 dollars.\n\nThe standard deviation of SalePrice is 79442.50 dollars. This indicates how much variation or dispersion there is in the SalePrice values. A low standard deviation means that the data points tend to be very close to the mean, while a high standard deviation means that the data points are spread out over a wider range of values. In this case, the standard deviation is relatively high, which suggests that the SalePrice values are quite spread out.\n'

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# 'TotRmsAbvGrd' distribution
df['TotRmsAbvGrd'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Summary statistics for 'TotRmsAbvGrd' using pandas statistics functions
print('Mean:', df['TotRmsAbvGrd'].mean())
print('Median:', df['TotRmsAbvGrd'].median())
print('Standard Deviation:', df['TotRmsAbvGrd'].std())
# Out:
# Mean: 6.517808219178082
# Median: 6.0
# Standard Deviation: 1.6253932905840505

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""
The mean number of rooms above ground is 6.52. This means that if we add up all the number of rooms in our dataset and divide by the total number of observations, we get an average of 6.52 rooms.

The median number of rooms above ground is 6.0. This means that half of the observations have a number of rooms above ground lower than 6.0, and half of the observations have a number of rooms above ground higher than 6.0.

The standard deviation of the number of rooms above ground is 1.63. This indicates how much variation or dispersion there is in the number of rooms above ground values. A low standard deviation means that the data points tend to be very close to the mean, while a high standard deviation means that the data points are spread out over a wider range of values. In this case, the standard deviation is relatively low, which suggests that the number of rooms above ground values are not too far from the mean.
"""
# Out:
# '\nThe mean number of rooms above ground is 6.52. This means that if we add up all the number of rooms in our dataset and divide by the total number of observations, we get an average of 6.52 rooms.\n\nThe median number of rooms above ground is 6.0. This means that half of the observations have a number of rooms above ground lower than 6.0, and half of the observations have a number of rooms above ground higher than 6.0.\n\nThe standard deviation of the number of rooms above ground is 1.63. This indicates how much variation or dispersion there is in the number of rooms above ground values. A low standard deviation means that the data points tend to be very close to the mean, while a high standard deviation means that the data points are spread out over a wider range of values. In this case, the standard deviation is relatively low, which suggests that the number of rooms above ground values are not too far from the mean.\n'

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# 'OverallCond' distribution
df['OverallCond'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Summary statistics for 'OverallCond' using pandas statistics functions
print('Mean:', df['OverallCond'].mean())
print('Median:', df['OverallCond'].median())
print('Standard Deviation:', df['OverallCond'].std())
# Out:
# Mean: 5.575342465753424
# Median: 5.0
# Standard Deviation: 1.1127993367127316

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""
The mean overall condition rating is 5.58. This means that if we add up all the overall condition ratings in our dataset and divide by the total number of observations, we get an average of 5.58.

The median overall condition rating is 5.0. This means that half of the observations have an overall condition rating lower than 5.0, and half of the observations have an overall condition rating higher than 5.0.

The standard deviation of the overall condition ratings is 1.11. This indicates how much variation or dispersion there is in the overall condition rating values. A low standard deviation means that the data points tend to be very close to the mean, while a high standard deviation means that the data points are spread out over a wider range of values. In this case, the standard deviation is relatively low, which suggests that the overall condition rating values are not too far from the mean.
"""
# Out:
# '\nThe mean overall condition rating is 5.58. This means that if we add up all the overall condition ratings in our dataset and divide by the total number of observations, we get an average of 5.58.\n\nThe median overall condition rating is 5.0. This means that half of the observations have an overall condition rating lower than 5.0, and half of the observations have an overall condition rating higher than 5.0.\n\nThe standard deviation of the overall condition ratings is 1.11. This indicates how much variation or dispersion there is in the overall condition rating values. A low standard deviation means that the data points tend to be very close to the mean, while a high standard deviation means that the data points are spread out over a wider range of values. In this case, the standard deviation is relatively low, which suggests that the overall condition rating values are not too far from the mean.\n'

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
# Replace None with appropriate code
below_average_condition = df[df['OverallCond'] < 5]
average_condition = df[df['OverallCond'] == 5]
above_average_condition = df[df['OverallCond'] > 5]

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %%
# Replace None with appropriate text
"""
The distributions of sale price for each of these subsets are all right-skewed, with the majority of the data points on the left side of the graph. This means that most of the houses in this dataset sold for less than $200,000. Houses in average condition are the most common, followed by houses in above average condition, and then houses in below average condition. These distributions are all fairly similar, with the exception of the below average condition houses, which have a much smaller number of houses in the higher price ranges. This makes sense, as houses in below average condition would be expected to sell for less than houses in average or above average condition. Houses in average condition have the highest number of houses in the higher price ranges, followed by houses in above average condition. This suggests that houses in average condition are more likely to sell for higher prices than houses in above average condition, which is surprising.

Houses in below average condition are the most likely to sell for less than $150,000, followed by houses in above average condition, and then houses in average condition. Houses in average condition are the most likely to sell for more than $150,000, followed by houses in above average condition, and then houses in below average condition. This adds to the evidence that houses in average condition are more likely to sell for higher prices than houses in above average condition, which is surprising.
"""
# Out:
# '\nThe distributions of sale price for each of these subsets are all right-skewed, with the majority of the data points on the left side of the graph. This means that most of the houses in this dataset sold for less than $200,000. Houses in average condition are the most common, followed by houses in above average condition, and then houses in below average condition. These distributions are all fairly similar, with the exception of the below average condition houses, which have a much smaller number of houses in the higher price ranges. This makes sense, as houses in below average condition would be expected to sell for less than houses in average or above average condition. Houses in average condition have the highest number of houses in the higher price ranges, followed by houses in above average condition. This suggests that houses in average condition are more likely to sell for higher prices than houses in above average condition, which is surprising.\n\nHouses in below average
# ...

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Select float and integer columns
numeric_columns = df.select_dtypes(include=['float64', 'int64'])

# Column most correlated with 'SalePrice'
corr = numeric_columns.corr()['SalePrice'].sort_values(ascending=False)

print(f'The column most correlated with SalePrice is "{corr.index[1]}" with a correlation of {corr[1]:.2f}')
# Out:
# The column most correlated with SalePrice is "OverallQual" with a correlation of 0.79

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Column most negatively correlated with 'SalePrice'
print(f'The column most negatively correlated with SalePrice is "{corr.index[-1]}" with a correlation of {corr[-1]:.2f}')
# Out:
# The column most negatively correlated with SalePrice is "KitchenAbvGr" with a correlation of -0.14

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df["OverallQual"],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df["KitchenAbvGr"],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title('Overall Quality vs Sale Price')
ax1.set_xlabel('Overall Quality')
ax1.set_ylabel("Sale Price")
ax2.set_title('Kitchen Above Grade vs Sale Price')
ax2.set_xlabel('Kitchen Above Grade')
ax2.set_ylabel("Sale Price");

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %%
# Replace None with appropriate text
"""
The column most positively correlated with SalePrice is "OverallQual" with a correlation of 0.79. This means that the higher the overall quality of the house, the higher the sale price. This makes sense, as a higher quality house would be expected to sell for more money. The box plot above confirms this, as the median sale price increases as the overall quality increases. The box plot also shows that the range of sale prices increases as the overall quality increases. This makes sense, as a higher quality house would be expected to have a wider range of sale prices. The box plot also shows that there are no outliers for houses with an overall quality of 1 or 2, but there are outliers for houses with an overall quality of 3 or higher.

The column most negatively correlated with SalePrice is "KitchenAbvGr" with a correlation of -0.14. This is not a strong relationship, but it does mean that the higher the number of kitchens above grade, the lower the sale price. This does not make sense, as a house with more kitchens would be expected to sell for more money. The box plot above confirms this, as the median sale price decreases as the number of kitchens above grade increases, with the exception of houses without any kitchens above grade. The box plot also shows that the range of sale prices decreases as the number of kitchens above grade increases, again, with the exception of houses without any kitchens above grade. This does not make sense, as a house with more kitchens would be expected to have a wider range of sale prices. The box plot also shows that there are no outliers for houses with 0 or 3 kitchens above grade, but there are outliers for houses with 1 or 2 kitchens above grade.
"""
# Out:
# '\nThe column most positively correlated with SalePrice is "OverallQual" with a correlation of 0.79. This means that the higher the overall quality of the house, the higher the sale price. This makes sense, as a higher quality house would be expected to sell for more money. The box plot above confirms this, as the median sale price increases as the overall quality increases. The box plot also shows that the range of sale prices increases as the overall quality increases. This makes sense, as a higher quality house would be expected to have a wider range of sale prices. The box plot also shows that there are no outliers for houses with an overall quality of 1 or 2, but there are outliers for houses with an overall quality of 3 or higher.\n\nThe column most negatively correlated with SalePrice is "KitchenAbvGr" with a correlation of -0.14. This is not a strong relationship, but it does mean that the higher the number of kitchens above grade, the lower the sale price. This does not make
# ...

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# YrSold
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: count, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %%
# Replace None with appropriate text
"""
The scatter plot shows that the majority of the houses in this dataset were sold when they were between 0 and 60 years old. The majority of the houses in this dataset sold for less than $250,000. Most of the houses that sold for more than $250,000 were between 0 and 60 years old. The houses that sold for more than $250,000 and were older than 60 years old were outliers.

Generally, the older the house, the less it sold for. However, there were some outliers, where the older the house, the more it sold for. This could be because the older houses were in better condition, or because they were in a more desirable location.
"""
# Out:
# '\nThe scatter plot shows that the majority of the houses in this dataset were sold when they were between 0 and 60 years old. The majority of the houses in this dataset sold for less than $250,000. Most of the houses that sold for more than $250,000 were between 0 and 60 years old. The houses that sold for more than $250,000 and were older than 60 years old were outliers.\n\nGenerally, the older the house, the less it sold for. However, there were some outliers, where the older the house, the more it sold for. This could be because the older houses were in better condition, or because they were in a more desirable location.\n'

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset! You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Generate some sample data
t = np.linspace(0, 2*np.pi, 1000)
y = np.sin(5*t) + np.sin(10*t) + np.sin(15*t)

# Compute the Fourier transform
fft = np.fft.fft(y)

# Sort the frequencies and corresponding magnitudes
freqs = np.fft.fftfreq(len(t), t[1]-t[0])
sorted_indices = np.argsort(freqs)
sorted_freqs = freqs[sorted_indices]
sorted_magnitudes = np.abs(fft)[sorted_indices]

# Create a figure and axis for the animation
fig, ax = plt.subplots()

# Set up the initial plot
line, = ax.plot(sorted_freqs, sorted_magnitudes)
ax.set_xlim(-30, 30)
ax.set_ylim(0, 250)

# Animation update function
def update(frame):
    # Shift the frequencies to simulate the animation
    shifted_freqs = sorted_freqs - frame
    line.set_data(shifted_freqs, sorted_magnitudes)
    return line,

# Create the animation
animation = FuncAnimation(fig, update, frames=np.arange(-30, 31), interval=100)

# Display the animation
plt.show()
